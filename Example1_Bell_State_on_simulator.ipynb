# %%
from qiskit import QuantumCircuit
from qiskit import ClassicalRegister, QuantumRegister
from qiskit import execute

qr = QuantumRegister(2)
cr = ClassicalRegister(2)
circuit = QuantumCircuit(qr, cr)

# %%
circuit.h(qr[1])
circuit.cx(qr[1], qr[0])
circuit.measure(qr, cr)

# %%
from qiskit.tools.visualization import circuit_drawer
circuit_drawer(circuit)
# Out:
# C:\Users\TOMASZSTOPA\Anaconda3\lib\site-packages\qiskit\tools\visualization\_circuit_visualization.py:206: DeprecationWarning: The current behavior for the default output will change in a future release. Instead of trying latex and falling back to mpl on failure it will just use "text" by default
#   '"text" by default', DeprecationWarning)
# WARNING: Unable to compile latex. Is `pdflatex` installed? Skipping latex circuit drawing...

# %%
from qiskit import Aer
backend = Aer.get_backend('qasm_simulator')
job = execute(circuit, backend)

# %%
job.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
result = job.result()

# %%
from qiskit.tools.visualization import plot_histogram
plot_histogram(result.get_counts(circuit))
